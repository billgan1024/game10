# %%
import scipy.io.wavfile as wavfile

x = wavfile.read("Project_1 (1).wav")
# Out:
# C:\Users\pbl\AppData\Local\Temp\ipykernel_10008\1559779140.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   x = wavfile.read("Project_1 (1).wav")

# %%
x
# Out:
# (44100,
#  array([[   2,    2],
#         [-231, -189],
#         [-365, -302],
#         ...,
#         [   0,    0],
#         [   0,    0],
#         [   0,    1]], shape=(1035278, 2), dtype=int16))

# %%
x[1].max()
# Out:
# np.int16(31973)
