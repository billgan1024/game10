# %%
import scipy.io.wavfile as wavfile

x = wavfile.read("rock.wav")
# Out:
# C:\Users\pbl\AppData\Local\Temp\ipykernel_9440\1384260264.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   x = wavfile.read("rock.wav")

# %%
x
# Out:
# (44100,
#  array([[ 4.96276654e-03,  5.57090249e-03],
#         [ 1.50757404e-02,  1.28293550e-02],
#         [ 1.26437489e-02,  1.33958776e-02],
#         ...,
#         [-4.63550896e-06, -1.34613410e-05],
#         [-5.55652923e-06, -1.31747465e-05],
#         [-6.33527043e-06, -1.29110249e-05]],
#        shape=(614491, 2), dtype=float32))

# %%
x[1].max()
# Out:
# np.float32(0.9757184)
